# %% [markdown]
# # Matplotlib
#
# Matplotlib jest podstawową biblioteką dotworzenia wykresów w pythonie.
#
# Strona pakietu: https://matplotlib.org/

# %%
#pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# puść ten kod, 
# jeżeli wywołujesz plik  w folderze rozwiąznaia, 
# a ramka danych znajduje się w folderze data
import os 
os.chdir('../')

# %%
df_grouped_electric_cars = pd.read_csv('data/df_by_year.csv')

# %%
df_grouped_electric_cars.head()
# Out:
#    Unnamed: 0  Model Year  Electric Range  Base MSRP  VIN (1-10)
# 0           0        1997            39.0        NaN           1
# 1           1        1998            58.0        NaN           1
# 2           2        1999            74.0        NaN           5
# 3           3        2000            58.0        NaN           7
# 4           4        2002            95.0        NaN           2

# %%
# Pandas ma wbudowaną metodę plot, która wykorzystuje matplotlib
df_grouped_electric_cars['Electric Range'].plot()
# Out:
# <Axes: >

# %%
# dodajmy tytuł
df_grouped_electric_cars['Electric Range'].plot()
plt.title('Average Electric Range by year')
# Out:
# Text(0.5, 1.0, 'Average Electric Range by year')

# %%
# dodajmy nazwy osi x/y
df_grouped_electric_cars['Electric Range'].plot()
plt.xlabel('Year')
plt.ylabel('Range')
plt.title('Average Electric Range by year')
# Out:
# Text(0.5, 1.0, 'Average Electric Range by year')

# %%
# dodajmy ograniczenia na minimalne i maksymalne wartości na osi x i y
df_grouped_electric_cars['Electric Range'].plot()
plt.xlabel('Year')
plt.ylabel('Range')
plt.title('Average Electric Range by year')
plt.xlim(0,15)
plt.ylim(0,300)
plt.show()

# %%
# Wiele linii na jednym wykresie
df_grouped_electric_cars[['Electric Range','Base MSRP']].plot()
plt.xlabel('Year')
plt.ylabel('Range')
plt.title('Average Electric Range by year')
plt.xlim(0,15)
plt.show()

# %%
# zmiana indeksu
df_grouped_electric_cars = df_grouped_electric_cars.set_index('Model Year')

# %%
# wykres slupkowy (bar plot) \
df_grouped_electric_cars['Electric Range'].plot(kind = 'bar')
plt.show()

# %%
# Wykresy bezpośrednio w matplotlib
plt.plot(df_grouped_electric_cars.index, df_grouped_electric_cars['Electric Range'])
plt.title('Average Electric Range')
plt.show()

# %%
# bar plot
plt.bar(df_grouped_electric_cars.index, df_grouped_electric_cars['Electric Range'])
plt.title('Average Electric Range')
plt.show()

# %% [markdown]
# ## Histogram
#
# Histogram jest wykresem, który kategoryzuje zmienną numeryczną na równe przedziały i pokazuje ich liczebność.

# %%
df = pd.read_csv('data/Electric_Vehicle_Population_Data.csv')

# %%
# Histogram zmiennej electric range
plt.hist(df['Electric Range'], bins= 15, color= 'red')
plt.title('Electric range')
plt.show()

# %%
plt.hist(df.loc[df['Electric Range']>0,'Electric Range'],bins=15, orientation='horizontal')
plt.show()

# %% [markdown]
# ## Wykres gęstości
#
# Wykres gęstości wizualnie będzie wyglądać bardzo podobnie histogramu, jednak na osi y mamy nie liczebność, a wykorzystuje prawdopodobieństwo.
# Interpretacja może przebiegać w ten sam sposób, co rozkładu.

# %%
plt.hist(df.loc[df['Electric Range']>0,'Electric Range'],bins=15, density = True)
plt.show()

# %% [markdown]
# ## Box Plot
# Inaczej nazywany wykresem ramka-wąsy. Pozwala na zbadanie mediany, wartości średniej, kwartyli oraz wartości odstających.
#
# ![boxplot](data\boxplot.png)
# źródło: https://www.labxchange.org/library/items/lb:LabXchange:d8863c77:html:1

# %%
# Box plot
plt.boxplot(df.loc[df['Electric Range']>0,'Electric Range'])
plt.show()

# %% [markdown]
# ### Wiele wykresów na jednym wydruku

# %%
fig, axs = plt.subplots(ncols=1, nrows=2)
axs[0].plot(df_grouped_electric_cars['Electric Range'])
axs[1].scatter(x=df_grouped_electric_cars.index, y=df_grouped_electric_cars['Base MSRP'])
plt.show()

# %%
axs
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
fig

# %%
fig, axs = plt.subplots(ncols=2, nrows=2)
axs[0,0].plot(df_grouped_electric_cars['Electric Range'])
axs[0,1].plot(df_grouped_electric_cars['Electric Range'])
