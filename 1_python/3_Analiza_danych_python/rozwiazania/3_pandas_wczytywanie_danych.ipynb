# %% [markdown]
# # Pandas
#
# Biblioteka pandas jest jedną z najpopularniejszych paczek wykorzystywanych w obróbce danych. To z niej będziemy najczęściej korzystać przy ładowaniu i przeglądaniu danych.
#
# Pandas działa w oparciu o ramki danych, w których mamy zmienne (kolumny) oraz wartości (wiersze). Wygląda to i działa podobnie jak arkusz w excelu.
#
# W trakcie kursu będziemy korzystac z wielu zbiorów danych. Teraz wczytamy pierwszy z nich.
#
# https://www.kaggle.com/datasets/adarshde/electric-vehicle-population-dataset/data

# %%
#import biblioteki
import pandas as pd

# %%
#pip install pandas

# %%
# puść ten kod, 
# jeżeli wywołujesz plik  w folderze rozwiąznaia, 
# a ramka danych znajduje się w folderze data
import os 
os.chdir('../')

# %%
# wczytanie danych
df = pd.read_csv("data/Electric_Vehicle_Population_Data.csv", sep = ',')

# %%
# Podejrzenie pierwszych kilku rekordów
df.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# 1             Not eligible due to low battery range              20
# 2           Clean Alternative Fuel Vehicle Eligible              84
# 3           Clean Alternative Fuel Vehicle Eligible             208
# 4           Clean Alternative Fuel Vehicle Eligible              42
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  43.0       202233958
# 1          0                  15.0       264425178
# 2          0                  11.0       114962025
# 3          0                   1.0       232724670
# 4          0                  14.0       221023589
#
#                   Vehicle Location  \
# 0    POINT (-122.300312 47.629782)
# 1  POINT (-120.2658133 46.4063477)
# 2    POINT (-122.201564 47.402358)
# 3    POINT (-122.206146 47.839957)
# 4    POINT (-120.611068 46.596645)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                                     PACIFICORP       5.307700e+10
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 3                         PUGET SOUND ENERGY INC       5.306105e+10
# 4                                     PACIFICORP       5.307700e+10

# %%
# Podejrzenie pierwszych 10 rekordów
df.head(10)
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
# 5  5YJ3E1EB6K       King  Redmond    WA      98052.0        2019   TESLA
# 6  5YJ3E1EB0J   Thurston     Yelm    WA      98597.0        2018   TESLA
# 7  3FA6P0SU8D     Kitsap  Poulsbo    WA      98370.0        2013    FORD
# 8  5YJSA1E21H       King  Redmond    WA      98052.0        2017   TESLA
# 9  5YJ3E1EA4J  Snohomish  Bothell    WA      98012.0        2018   TESLA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
# 5     MODEL 3          Battery Electric Vehicle (BEV)
# 6     MODEL 3          Battery Electric Vehicle (BEV)
# 7      FUSION  Plug-in Hybrid Electric Vehicle (PHEV)
# 8     MODEL S          Battery Electric Vehicle (BEV)
# 9     MODEL 3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# 1             Not eligible due to low battery range              20
# 2           Clean Alternative Fuel Vehicle Eligible              84
# 3           Clean Alternative Fuel Vehicle Eligible             208
# 4           Clean Alternative Fuel Vehicle Eligible              42
# 5           Clean Alternative Fuel Vehicle Eligible             220
# 6           Clean Alternative Fuel Vehicle Eligible             215
# 7             Not eligible due to low battery range              19
# 8           Clean Alternative Fuel Vehicle Eligible             210
# 9           Clean Alternative Fuel Vehicle Eligible             215
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0          0                  43.0       202233958
# 1          0                  15.0       264425178
# 2          0                  11.0       114962025
# 3          0                   1.0       232724670
# 4          0                  14.0       221023589
# 5          0                  48.0       296777442
# 6          0                   2.0       311913577
# 7          0                  23.0       136752115
# 8          0                  45.0       241259105
# 9          0                   1.0       118035830
#
#                   Vehicle Location  \
# 0    POINT (-122.300312 47.629782)
# 1  POINT (-120.2658133 46.4063477)
# 2    POINT (-122.201564 47.402358)
# 3    POINT (-122.206146 47.839957)
# 4    POINT (-120.611068 46.596645)
# 5  POINT (-122.1207376 47.6705374)
# 6  POINT (-122.5715761 46.9095798)
# 7  POINT (-122.6368884 47.7469547)
# 8  POINT (-122.1207376 47.6705374)
# 9    POINT (-122.206146 47.839957)
#
#                                 Electric Utility  2020 Census Tract
# 0   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 1                                     PACIFICORP       5.307700e+10
# 2  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 3                         PUGET SOUND ENERGY INC       5.306105e+10
# 4                                     PACIFICORP       5.307700e+10
# 5  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 6                         PUGET SOUND ENERGY INC       5.306701e+10
# 7                         PUGET SOUND ENERGY INC       5.303509e+10
# 8  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 9                         PUGET SOUND ENERGY INC       5.306105e+10

# %%
# Podejrzenie ostatnich 10 rekordów.
df.tail(10)
# Out:
#         VIN (1-10)        County              City State  Postal Code  \
# 191397  1FTVW1EL1P       Spokane           Spokane    WA      99202.0
# 191398  5YJSA1V23F      San Juan     Friday Harbor    WA      98250.0
# 191399  5YJ3E1EA5J        Pierce  University Place    WA      98466.0
# 191400  7SAYGDEE6P     Snohomish          Lynnwood    WA      98087.0
# 191401  2C4RC1N76K     Snohomish             Brier    WA      98036.0
# 191402  5YJ3E1EA0K        Pierce            Sumner    WA      98390.0
# 191403  JN1BF0BA7P        Pierce          Wilkeson    WA      98396.0
# 191404  7SAYGDEE4R          King         Fall City    WA      98024.0
# 191405  7SAXCBE65N  Grays Harbor          Aberdeen    WA      98520.0
# 191406  7SAYGAEEXP        Benton          Richland    WA      99352.0
#
#         Model Year      Make     Model  \
# 191397        2023      FORD     F-150
# 191398        2015     TESLA   MODEL S
# 191399        2018     TESLA   MODEL 3
# 191400        2023     TESLA   MODEL Y
# 191401        2019  CHRYSLER  PACIFICA
# 191402        2019     TESLA   MODEL 3
# 191403        2023    NISSAN     ARIYA
# 191404        2024     TESLA   MODEL Y
# 191405        2022     TESLA   MODEL X
# 191406        2023     TESLA   MODEL Y
#
#                          Electric Vehicle Type  \
# 191397          Battery Electric Vehicle (BEV)
# 191398          Battery Electric Vehicle (BEV)
# 191399          Battery Electric Vehicle (BEV)
# 191400          Battery Electric Vehicle (BEV)
# 191401  Plug-in Hybrid Electric Vehicle (PHEV)
# 191402          Battery Electric Vehicle (BEV)
# 191403          Battery Electric Vehicle (BEV)
# 191404          Battery Electric Vehicle (BEV)
# 191405          Battery Electric Vehicle (BEV)
# 191406          Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 191397  Eligibility unknown as battery range has not b...               0
# 191398            Clean Alternative Fuel Vehicle Eligible             208
# 191399            Clean Alternative Fuel Vehicle Eligible             215
# 191400  Eligibility unknown as battery range has not b...               0
# 191401            Clean Alternative Fuel Vehicle Eligible              32
# 191402            Clean Alternative Fuel Vehicle Eligible             220
# 191403  Eligibility unknown as battery range has not b...               0
# 191404  Eligibility unknown as battery range has not b...               0
# 191405  Eligibility unknown as battery range has not b...               0
# 191406  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 191397          0                   3.0       262528724
# 191398          0                  40.0       185961184
# 191399          0                  28.0       216543918
# 191400          0                  21.0       223892560
# 191401      39995                   1.0       473832901
# 191402          0                  31.0       314927896
# 191403          0                  31.0       236213120
# 191404          0                   5.0       261335896
# 191405          0                  19.0       219273491
# 191406          0                   8.0       233761440
#
#                        Vehicle Location  \
# 191397     POINT (-117.38497 47.657214)
# 191398  POINT (-123.0679454 48.5327669)
# 191399   POINT (-122.538546 47.2298959)
# 191400     POINT (-122.27336 47.861417)
# 191401    POINT (-122.287143 47.812199)
# 191402  POINT (-122.2337855 47.2055969)
# 191403  POINT (-122.0478543 47.1075591)
# 191404    POINT (-121.903093 47.567116)
# 191405    POINT (-123.807422 46.978243)
# 191406  POINT (-119.2958528 46.2421419)
#
#                                          Electric Utility  2020 Census Tract
# 191397                      MODERN ELECTRIC WATER COMPANY       5.306301e+10
# 191398  BONNEVILLE POWER ADMINISTRATION||ORCAS POWER &...       5.305596e+10
# 191399  BONNEVILLE POWER ADMINISTRATION||CITY OF TACOM...       5.305307e+10
# 191400                             PUGET SOUND ENERGY INC       5.306104e+10
# 191401                             PUGET SOUND ENERGY INC       5.306105e+10
# 191402      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 191403      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.305307e+10
# 191404      PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303303e+10
# 191405  BONNEVILLE POWER ADMINISTRATION||PUD NO 1 OF G...       5.302700e+10
# 191406  BONNEVILLE POWER ADMINISTRATION||CITY OF RICHL...       5.300501e+10

# %%
# Informacje o zbiorze
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191407 entries, 0 to 191406
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         191407 non-null  object
#  1   County                                             191403 non-null  object
#  2   City                                               191403 non-null  object
#  3   State                                              191407 non-null  object
#  4   Postal Code                                        191403 non-null  float64
#  5   Model Year                                         191407 non-null  int64
#  6   Make                                               191407 non-null  object
#  7   Model                                              191407 non-null  object
#  8   Electric Vehicle Type                              191407 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  191407 non-null  object
#  10  Electric Range                                     191407 non-null  int64
#  11  Base MSRP                                          191407 non-null  int64
#  12  Legislative District                               190993 non-null  float64
#  13  DOL Vehicle ID                                     191407 non-null  int64
#  14  Vehicle Location                                   191399 non-null  object
#  15  Electric Utility                                   191403 non-null  object
#  16  2020 Census Tract                                  191403 non-null  float64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 24.8+ MB

# %%
# Liczba wierszy i kolumn
df.shape
# Out:
# (191407, 17)

# %%
# Podstawowe statystyki
df.describe()
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  191403.000000  191407.000000   191407.000000  191407.000000
# mean    98177.823603    2020.732335       55.657442     994.773258
# std      2392.808886       2.990487       90.151930    8050.523372
# min      1731.000000    1997.000000        0.000000       0.000000
# 25%     98052.000000    2019.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 75%     98371.000000    2023.000000       72.000000       0.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         190993.000000    1.914070e+05       1.914030e+05
# mean              29.016880    2.237202e+08       5.297759e+10
# std               14.909417    7.398058e+07       1.573588e+09
# min                1.000000    4.385000e+03       1.001020e+09
# 25%               17.000000    1.861622e+08       5.303301e+10
# 50%               33.000000    2.328176e+08       5.303303e+10
# 75%               42.000000    2.589708e+08       5.305307e+10
# max               49.000000    4.792548e+08       5.602100e+10

# %%
df.describe(percentiles=[0.01,0.99])
# Out:
#          Postal Code     Model Year  Electric Range      Base MSRP  \
# count  191403.000000  191407.000000   191407.000000  191407.000000
# mean    98177.823603    2020.732335       55.657442     994.773258
# std      2392.808886       2.990487       90.151930    8050.523372
# min      1731.000000    1997.000000        0.000000       0.000000
# 1%      98003.000000    2012.000000        0.000000       0.000000
# 50%     98125.000000    2022.000000        0.000000       0.000000
# 99%     99343.000000    2024.000000      322.000000   53400.000000
# max     99577.000000    2025.000000      337.000000  845000.000000
#
#        Legislative District  DOL Vehicle ID  2020 Census Tract
# count         190993.000000    1.914070e+05       1.914030e+05
# mean              29.016880    2.237202e+08       5.297759e+10
# std               14.909417    7.398058e+07       1.573588e+09
# min                1.000000    4.385000e+03       1.001020e+09
# 1%                 1.000000    4.639810e+06       5.300501e+10
# 50%               33.000000    2.328176e+08       5.303303e+10
# 99%               49.000000    4.766929e+08       5.307301e+10
# max               49.000000    4.792548e+08       5.602100e+10

# %%
# Podsumowanie danych tekstowych
df.describe(include = 'object')
# Out:
#         VIN (1-10)  County     City   State    Make    Model  \
# count       191407  191403   191403  191407  191407   191407
# unique       11487     197      744      46      42      147
# top     7SAYGDEE6P    King  Seattle      WA   TESLA  MODEL Y
# freq          1236   99076    31436  190993   84670    39521
#
#                  Electric Vehicle Type  \
# count                           191407
# unique                               2
# top     Battery Electric Vehicle (BEV)
# freq                            149687
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  \
# count                                              191407
# unique                                                  3
# top     Eligibility unknown as battery range has not b...
# freq                                               102133
#
#                        Vehicle Location  \
# count                            191399
# unique                              891
# top     POINT (-122.1207376 47.6705374)
# freq                               4858
#
#                                      Electric Utility
# count                                          191403
# unique                                             75
# top     PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# freq                                            70546
